# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./pandas practice/product_ratings_january_2022.csv')
df = df.set_index('Date')
df.plot(kind= 'line', title= 'Ice Cream Sales in January 2022', xlabel='Daily Ratings', ylabel='Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Sales in January 2022'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
df.plot.barh(stacked=True, title= 'Ice Cream Sales in January 2022', xlabel='Daily Ratings', ylabel='Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Sales in January 2022'}, xlabel='Daily Ratings', ylabel='Scores'>
