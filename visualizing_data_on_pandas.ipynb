# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.read_csv('./pandas practice/product_ratings_january_2022.csv', parse_dates=['Date'])
df = df.set_index('Date')

# df.plot(kind='line', title='Ice Cream Sales in January 2022', xlabel='Daily Ratings', ylabel='Scores')
# plt.show()

df.plot.area()
# plt.show()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.area()
# Out:
# <Axes: xlabel='Date'>
